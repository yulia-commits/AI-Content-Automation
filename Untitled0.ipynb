# %%
API_KEY="AIzaSyCWS4R_cZeAZD0wWVz_w3Onkulaa_n2Rtc"

# %%
# !pip install google-genai

# %%
from google import genai

# ЧТЕНИЕ ИСХОДНОГО ФАЙЛА
with open("article.txt", "r", encoding="utf-8") as file:
    long_article = file.read()

# ФОРМИРОВАНИЕ ПРОМПТА И PAYLOAD
my_prompt = f"""
Прочитай и кратко проанализируй следующий текст.
Выдели три ключевых тезиса и представь их в виде маркированного списка.
Текст для анализа: {long_article}
"""

# ЗАПРОС К МОДЕЛИ (INFERENCE)
# Ключ API_KEY берется из Ячейки 1
client = genai.Client(api_key=API_KEY)
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=my_prompt
)

# СОХРАНЕНИЕ ОТВЕТА В ФАЙЛ SUMMARY.TXT
if response.text:
    with open("summary.txt", "w", encoding="utf-8") as file:
        file.write(response.text)

    print("✅ Скрипт успешно отработал и сохранил файл!")
# Out:
# ✅ Скрипт успешно отработал и сохранил файл!
